# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
WeatherPy_vacation_df = (r"C:\Users\kevin\Documents\myrepo\World_Weather_Analysis\Weather_data\WeatherPy_database.csv")

# %%
# Store the CSV you saved created in part one into a DataFrame.

weatherpy_vacation_df = pd.read_csv(r"C:\Users\kevin\Documents\myrepo\World_Weather_Analysis\Weather_data\WeatherPy_database.csv")
weatherpy_vacation_df.head(500)
# Out:
#      City_ID                   City Country                 Date    Lat  \
# 0          0            Yellowknife      CA  2020-07-15 22:57:24  62.46
# 1          1                  Mpika      ZM  2020-07-15 22:57:24 -11.83
# 2          2                 Marawi      PH  2020-07-15 22:57:24   8.00
# 3          3                  Bluff      NZ  2020-07-15 22:57:24 -46.60
# 4          4                Rajapur      IN  2020-07-15 22:57:25  25.38
# ..       ...                    ...     ...                  ...    ...
# 495      495              Boguchany      RU  2020-07-15 22:58:39  58.38
# 496      496                Angoram      PG  2020-07-15 22:58:39  -4.06
# 497      497                   Luan      CH  2020-07-15 22:58:39  46.36
# 498      498                 Norsup      VU  2020-07-15 22:58:40 -16.07
# 499      499  Los Llanos De Aridane      ES  2020-07-15 22:58:40  28.66
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# ...

# %%
#get the data types.
weatherpy_vacation_df.dtypes
# Out:
# City_ID                  int64
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# Snowfall                 int64
# Rainfall               float64
# dtype: object

# %%
Puerto_Escondido_df = weatherpy_vacation_df.loc[weatherpy_vacation_df["City"]=="Puerto Escondido"]
Puerto_Escondido_df
# Out:
#      City_ID              City Country                 Date    Lat    Lng  \
# 104      104  Puerto Escondido      MX  2020-07-15 22:57:40  15.85 -97.07
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  Snowfall  \
# 104      86.0        70          75        5.82       broken clouds         0
#
#      Rainfall
# 104       0.0

# %%
Guerrero_Negro_df = weatherpy_vacation_df.loc[weatherpy_vacation_df["City"]=="Guerrero Negro"]
Guerrero_Negro_df
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 63       63  Guerrero Negro      MX  2020-07-15 22:57:34  27.98 -114.06
#
#     Max Temp  Humidity  Cloudiness  Wind Speed Current Description  Snowfall  \
# 63     76.87        54          95       20.36     overcast clouds         0
#
#     Rainfall
# 63       0.0

# %%
Lompoc_df = weatherpy_vacation_df.loc[weatherpy_vacation_df["City"]=="Lompoc"]
Lompoc_df
# Out:
#      City_ID    City Country                 Date    Lat     Lng  Max Temp  \
# 149      149  Lompoc      US  2020-07-15 22:52:54  34.64 -120.46      69.8
#
#      Humidity  Cloudiness  Wind Speed Current Description  Snowfall  Rainfall
# 149        60           3       14.99           clear sky         0       0.0

# %%
Half_Moon_Bay_df = weatherpy_vacation_df.loc[weatherpy_vacation_df["City"]=="Half Moon Bay"]
Half_Moon_Bay_df
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Snowfall, Rainfall]
# Index: []

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyD8yzsbGbeDg20BCXACfgfj8Lz7JzdHQLs")
# Latitude-longitude pairs
Puerto_Escondido = (15.85, -97.07)
Guerrero_Negro = (27.98, -114.06)
Lompoc = (34.64, -120.46)
Half_Moon_Bay = (37.46, -122.43)
fig = gmaps.figure()
fourcities = gmaps.directions_layer(Puerto_Escondido, Guerrero_Negro, waypoints=[Lompoc, Half_Moon_Bay], travel_mode='DRIVING')
fig.add_layer(fourcities)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
